# %% [markdown]
# # Libraries

# %%
import datetime as dt

import pandas as pd

from openbb_terminal.sdk import openbb
import quantstats as qs
import backtrader as bt

# %% [markdown]
# #  Functions

# %%
def openbb_data_to_bt_data(symbol, start_date, end_date):
    
    df = openbb.stocks.load(symbol, start_date=start_date, end_date=end_date)
    
    fn = f"{symbol.lower()}.csv"
    df.to_csv(fn)
    
    return bt.feeds.YahooFinanceCSVData(
        dataname=fn,
        fromdate=dt.datetime.strptime(start_date, '%Y-%m-%d'),
        todate=dt.datetime.strptime(end_date, '%Y-%m-%d')
    )


def last_day_of_month(any_day):
    # The day 28 exists in every month. 4 days later, it's always next month
    next_month = any_day.replace(day=28) + dt.timedelta(days=4)
    
    # subtracting the number of the current day brings us back one month
    return (next_month - dt.timedelta(days=next_month.day)).day

# %% [markdown]
# # Backtrader Strategy

# %%
class MonthlyFlows(bt.Strategy):
    
    params = (
        ("end_of_month", 23),
        ("start_of_month", 7),
    )
    
    def __init__(self):
        self.order = None
        self.dataclose = self.datas[0].close
        
    def notify_order(self, order):
        # No more orders
        self.order = None    
    
    def next(self):
        
        # Get today's date, day of month, and last day of current month
        dt_ = self.datas[0].datetime.date(0)
        dom = dt_.day
        ldm = last_day_of_month(dt_)
        
        # If an order is pending, exit
        if self.order:
            return
        
        # Check if we are in the market
        if not self.position:
            
            # We're in the first week of the month, sell
            if dom <= self.params.start_of_month:

                # Sell the entire portfolio
                self.order = self.order_target_percent(target=-1)
                
                print(f"Created SELL of {self.order.size} at {self.data_close[0]} on day {dom}")
            
            # We're in the last week of the month, buy
            if dom >= self.params.end_of_month:

                # Buy the entire portfolio
                self.order = self.order_target_percent(target=1)
                
                print(f"Created BUY of {self.order.size} {self.data_close[0]} on day {dom}")
        
        # We are not in the market
        else:
            
            # If we're long
            if self.position.size > 0:
                
                # And not within the last week of the month, close
                if not self.params.end_of_month <= dom <= ldm:
                    
                    print(f"Created CLOSE of {self.position.size} at {self.data_close[0]} on day {dom}")

                    self.order = self.order_target_percent(target=0.0)
            
            # If we're short
            if self.position.size < 0:
                
                # And not within the first week of the month, close
                if not 1 <= dom <= self.params.start_of_month:
                    
                    print(f"Created CLOSE of {self.position.size} at {self.data_close[0]} on day {dom}")

                    # self.order = self.close()
                    self.order = self.order_target_percent(target=0.0)

# %% [markdown]
# # Backtest

# %%
data = openbb_data_to_bt_data(
    "TLT", 
    start_date="2002-01-01",
    end_date="2022-06-30"
)

cerebro = bt.Cerebro(stdstats=False)

cerebro.adddata(data)
cerebro.broker.setcash(1000.0)

cerebro.addstrategy(MonthlyFlows)

cerebro.addobserver(bt.observers.Value)

cerebro.addanalyzer(
    bt.analyzers.Returns, _name="returns"
)
cerebro.addanalyzer(
    bt.analyzers.TimeReturn, _name="time_return"
)

backtest_result = cerebro.run()
# Out:
# Loading Daily data for TLT with starting period 2002-07-30.
# Created BUY of 24 41.24 on day 30
# Created CLOSE of 24 at 41.99 on day 1
# Created SELL of -23 at 42.42 on day 2
# Created CLOSE of -23 at 42.34 on day 8
# Created BUY of 23 43.45 on day 23
# Created CLOSE of 23 at 44.73 on day 3
# Created SELL of -23 at 44.72 on day 4
# Created CLOSE of -23 at 44.37 on day 9
# Created BUY of 23 45.77 on day 23
# Created CLOSE of 23 at 45.36 on day 1
# Created SELL of -23 at 45.62 on day 2
# Created CLOSE of -23 at 45.74 on day 8
# Created BUY of 24 43.0 on day 23
# Created CLOSE of 24 at 44.04 on day 1
# Created SELL of -24 at 43.85 on day 4
# Created CLOSE of -24 at 45.3 on day 8
# Created BUY of 23 43.99 on day 25
# Created CLOSE of 23 at 43.86 on day 2
# Created SELL of -23 at 43.93 on day 3
# Created CLOSE of -23 at 44.59 on day 9
# Created BUY of 22 44.98 on day 23
# Created CLOSE of 22 at 44.62 on day 2
# Created SELL of -22 at 44.73 on day 3
# Created CLOSE of -22 at 44.99 on day 8
# Created BUY of 22 45.23 on day 23
# Created CLOSE of 22 at 45.61 on day 3
# Created SELL of -22 at 45.81 on day 4
# Created CLOSE of -22 at 45.57 on day 10
# Created BUY of 22 46.04 on day 24
# Created BUY of 22 46.26 on day 25
# Created BUY of 21 46.58 on day 26
# Created CLOSE of 21 at 47.01 on day 3
# Created SELL of -21 at 47.04 on day 4
# Created CLOSE of -21 at 47.42 on day 10
# Created BUY of 22 45.54 on day 24
# Created CLOSE of 22 at 46.18 on day 1
# Created SELL of -22 at 45.7 on day 2
# Created CLOSE of -22 at 45.8 on day 8
# Created BUY of 22 46.0 on day 23
# Created CLOSE of 22 at 46.82 on day 1
# Created SELL of -22 at 46.45 on day 2
# Created CLOSE of -22 at 47.59 on day 8
# Created BUY of 20 50.41 on day 23
# Created CLOSE of 20 at 49.39 on day 2
# Created SELL of -20 at 49.79 on day 3
# Created CLOSE of -20 at 50.06 on day 9
# Created BUY of 20 49.81 on day 23
# Created CLOSE of 20 at 48.61 on day 1
# Created SELL of -19 at 48.74 on day 2
# Created CLOSE of -19 at 47.77 on day 8
# Created BUY of 21 45.89 on day 23
# Created CLOSE of 21 at 43.95 on day 1
# Created SELL of -21 at 44.33 on day 4
# Created CLOSE of -21 at 44.56 on day 8
# Created BUY of 21 44.06 on day 25
# Created CLOSE of 21 at 43.9 on day 2
# Created SELL of -21 at 43.97 on day 3
# Created CLOSE of -21 at 44.51 on day 8
# Created BUY of 20 45.76 on day 23
# Created CLOSE of 20 at 47.02 on day 1
# Created SELL of -20 at 46.8 on day 2
# Created CLOSE of -20 at 45.48 on day 8
# Created BUY of 21 45.31 on day 23
# Created CLOSE of 21 at 45.55 on day 3
# Created SELL of -21 at 45.81 on day 4
# Created CLOSE of -21 at 45.01 on day 10
# Created BUY of 21 46.28 on day 24
# Created CLOSE of 21 at 45.67 on day 1
# Created SELL of -21 at 45.86 on day 2
# Created CLOSE of -21 at 46.19 on day 8
# Created BUY of 20 46.54 on day 23
# Created CLOSE of 20 at 45.99 on day 2
# Created SELL of -20 at 45.87 on day 5
# Created CLOSE of -20 at 46.55 on day 8
# Created BUY of 19 47.59 on day 23
# Created CLOSE of 19 at 47.31 on day 2
# Created SELL of -19 at 47.55 on day 3
# Created CLOSE of -19 at 47.93 on day 9
# Created BUY of 19 48.06 on day 23
# Created CLOSE of 19 at 48.47 on day 1
# Created SELL of -19 at 48.16 on day 2
# Created CLOSE of -19 at 49.51 on day 8
# Created BUY of 17 50.04 on day 23
# Created CLOSE of 17 at 49.01 on day 1
# Created SELL of -17 at 47.8 on day 2
# Created CLOSE of -17 at 47.43 on day 8
# Created BUY of 18 46.33 on day 23
# Created CLOSE of 18 at 46.16 on day 3
# Created SELL of -18 at 45.85 on day 4
# Created CLOSE of -18 at 44.9 on day 10
# Created BUY of 19 45.38 on day 24
# Created CLOSE of 19 at 45.57 on day 1
# Created SELL of -19 at 45.45 on day 2
# Created CLOSE of -19 at 45.37 on day 8
# Created BUY of 19 45.86 on day 23
# Created CLOSE of 19 at 46.56 on day 1
# Created SELL of -19 at 47.05 on day 2
# Created CLOSE of -19 at 47.02 on day 8
# Created BUY of 19 47.38 on day 23
# Created CLOSE of 19 at 47.24 on day 2
# Created SELL of -19 at 47.44 on day 3
# Created CLOSE of -19 at 48.22 on day 9
# Created BUY of 18 48.18 on day 23
# Created CLOSE of 18 at 49.2 on day 1
# Created SELL of -18 at 48.72 on day 2
# Created CLOSE of -18 at 49.08 on day 8
# Created BUY of 17 50.22 on day 23
# Created CLOSE of 17 at 49.37 on day 1
# Created SELL of -17 at 49.44 on day 4
# Created CLOSE of -17 at 49.65 on day 8
# Created BUY of 17 50.74 on day 25
# Created CLOSE of 17 at 50.18 on day 1
# Created SELL of -17 at 50.25 on day 2
# Created CLOSE of -17 at 49.6 on day 8
# Created BUY of 17 50.35 on day 23
# Created CLOSE of 17 at 49.2 on day 1
# Created SELL of -17 at 49.01 on day 2
# Created CLOSE of -17 at 50.78 on day 8
# Created BUY of 16 50.42 on day 23
# Created CLOSE of 16 at 50.7 on day 3
# Created SELL of -16 at 50.17 on day 4
# Created CLOSE of -16 at 50.67 on day 10
# Created BUY of 15 52.22 on day 24
# Created CLOSE of 15 at 52.31 on day 1
# Created SELL of -15 at 52.43 on day 2
# Created CLOSE of -15 at 53.83 on day 8
# Created BUY of 15 52.05 on day 23
# Created CLOSE of 15 at 51.61 on day 1
# Created SELL of -15 at 51.54 on day 2
# Created CLOSE of -15 at 51.78 on day 8
# Created BUY of 15 50.68 on day 23
# Created CLOSE of 15 at 51.56 on day 1
# Created SELL of -15 at 51.55 on day 4
# Created CLOSE of -15 at 51.36 on day 8
# Created BUY of 15 52.97 on day 25
# Created CLOSE of 15 at 53.37 on day 2
# Created SELL of -15 at 53.51 on day 3
# Created CLOSE of -15 at 52.82 on day 9
# Created BUY of 15 54.57 on day 23
# Created CLOSE of 15 at 55.73 on day 1
# Created SELL of -14 at 55.86 on day 2
# Created CLOSE of -14 at 55.87 on day 8
# Created BUY of 15 55.78 on day 23
# Created CLOSE of 15 at 55.56 on day 1
# Created SELL of -15 at 55.04 on day 5
# Created CLOSE of -15 at 55.23 on day 8
# Created BUY of 15 54.4 on day 25
# Created CLOSE of 15 at 54.14 on day 1
# Created SELL of -15 at 53.96 on day 2
# Created CLOSE of -15 at 53.6 on day 8
# Created BUY of 15 55.13 on day 23
# Created CLOSE of 15 at 55.89 on day 1
# Created SELL of -15 at 55.94 on day 2
# Created CLOSE of -15 at 55.08 on day 8
# Created BUY of 15 54.44 on day 23
# Created CLOSE of 15 at 53.78 on day 3
# Created SELL of -15 at 53.95 on day 4
# Created CLOSE of -15 at 54.17 on day 10
# Created BUY of 15 53.54 on day 24
# Created CLOSE of 15 at 52.92 on day 1
# Created SELL of -15 at 52.68 on day 2
# Created CLOSE of -15 at 52.92 on day 8
# Created BUY of 15 53.46 on day 23
# Created CLOSE of 15 at 53.27 on day 1
# Created SELL of -15 at 53.29 on day 2
# Created CLOSE of -15 at 53.73 on day 8
# Created BUY of 15 54.65 on day 23
# Created CLOSE of 15 at 54.87 on day 3
# Created SELL of -15 at 55.0 on day 4
# Created CLOSE of -15 at 54.87 on day 9
# Created BUY of 14 55.21 on day 23
# Created CLOSE of 14 at 54.02 on day 1
# Created SELL of -15 at 54.12 on day 2
# Created CLOSE of -15 at 54.23 on day 8
# Created BUY of 14 54.71 on day 23
# Created CLOSE of 14 at 54.48 on day 1
# Created SELL of -14 at 54.1 on day 2
# Created CLOSE of -14 at 53.33 on day 8
# Created BUY of 15 53.25 on day 23
# Created CLOSE of 15 at 52.32 on day 3
# Created SELL of -15 at 52.26 on day 4
# Created CLOSE of -15 at 51.53 on day 10
# Created BUY of 15 51.45 on day 24
# Created CLOSE of 15 at 50.48 on day 1
# Created SELL of -15 at 50.61 on day 2
# Created CLOSE of -15 at 50.75 on day 8
# Created BUY of 15 51.31 on day 23
# Created CLOSE of 15 at 50.99 on day 1
# Created SELL of -15 at 51.65 on day 2
# Created CLOSE of -15 at 51.94 on day 8
# Created BUY of 15 50.82 on day 23
# Created CLOSE of 15 at 51.31 on day 3
# Created SELL of -15 at 50.9 on day 5
# Created CLOSE of -15 at 51.59 on day 10
# Created BUY of 14 52.15 on day 24
# Created CLOSE of 14 at 52.47 on day 1
# Created SELL of -14 at 52.67 on day 2
# Created CLOSE of -14 at 52.91 on day 8
# Created BUY of 14 53.51 on day 23
# Created CLOSE of 14 at 54.1 on day 1
# Created SELL of -14 at 53.76 on day 5
# Created CLOSE of -14 at 53.83 on day 8
# Created BUY of 14 55.67 on day 25
# Created CLOSE of 14 at 55.27 on day 2
# Created SELL of -14 at 55.19 on day 3
# Created CLOSE of -14 at 54.78 on day 9
# Created BUY of 14 53.97 on day 23
# Created CLOSE of 14 at 55.89 on day 1
# Created SELL of -14 at 55.66 on day 2
# Created CLOSE of -14 at 55.62 on day 8
# Created BUY of 14 56.3 on day 24
# Created CLOSE of 14 at 57.01 on day 1
# Created SELL of -14 at 57.11 on day 4
# Created CLOSE of -14 at 56.27 on day 8
# Created BUY of 14 55.91 on day 26
# Created CLOSE of 14 at 55.73 on day 3
# Created SELL of -14 at 56.06 on day 4
# Created CLOSE of -14 at 55.92 on day 8
# Created BUY of 15 54.82 on day 23
# Created CLOSE of 15 at 54.71 on day 1
# Created SELL of -14 at 54.78 on day 2
# Created CLOSE of -14 at 55.37 on day 8
# Created BUY of 14 55.81 on day 23
# Created CLOSE of 14 at 56.6 on day 1
# Created SELL of -14 at 56.88 on day 2
# Created CLOSE of -14 at 56.98 on day 8
# Created BUY of 14 56.0 on day 23
# Created CLOSE of 14 at 55.77 on day 2
# Created SELL of -14 at 55.7 on day 3
# Created CLOSE of -14 at 55.18 on day 9
# Created BUY of 15 56.0 on day 23
# Created CLOSE of 15 at 56.22 on day 1
# Created SELL of -15 at 56.19 on day 2
# Created CLOSE of -15 at 56.31 on day 8
# Created BUY of 15 54.95 on day 23
# Created CLOSE of 15 at 54.59 on day 1
# Created SELL of -15 at 54.84 on day 4
# Created CLOSE of -15 at 53.45 on day 8
# Created BUY of 16 53.72 on day 25
# Created CLOSE of 16 at 54.61 on day 2
# Created SELL of -16 at 54.27 on day 3
# Created CLOSE of -16 at 53.64 on day 9
# Created BUY of 15 54.95 on day 23
# Created CLOSE of 15 at 56.0 on day 1
# Created SELL of -15 at 56.14 on day 2
# Created CLOSE of -15 at 55.38 on day 8
# Created BUY of 15 56.19 on day 23
# Created CLOSE of 15 at 57.16 on day 4
# Created SELL of -15 at 57.61 on day 5
# Created CLOSE of -15 at 58.73 on day 10
# Created BUY of 15 56.88 on day 24
# Created CLOSE of 15 at 57.59 on day 1
# Created SELL of -15 at 57.77 on day 2
# Created CLOSE of -15 at 57.15 on day 8
# Created BUY of 15 58.54 on day 23
# Created CLOSE of 15 at 59.06 on day 1
# Created SELL of -15 at 59.24 on day 2
# Created CLOSE of -15 at 58.93 on day 8
# Created BUY of 14 60.99 on day 23
# Created CLOSE of 14 at 61.91 on day 3
# Created SELL of -14 at 61.9 on day 4
# Created CLOSE of -14 at 59.59 on day 10
# Created BUY of 15 59.61 on day 24
# Created CLOSE of 15 at 61.91 on day 2
# Created SELL of -15 at 61.83 on day 3
# Created CLOSE of -15 at 62.04 on day 8
# Created BUY of 15 63.16 on day 23
# Created CLOSE of 15 at 62.69 on day 1
# Created SELL of -15 at 62.04 on day 4
# Created CLOSE of -15 at 61.68 on day 8
# Created BUY of 16 59.95 on day 25
# Created CLOSE of 16 at 61.87 on day 3
# Created SELL of -16 at 61.27 on day 4
# Created CLOSE of -16 at 61.83 on day 10
# Created BUY of 16 62.96 on day 24
# Created CLOSE of 16 at 62.32 on day 1
# Created SELL of -16 at 62.46 on day 2
# Created CLOSE of -16 at 62.62 on day 8
# Created BUY of 16 61.81 on day 23
# Created CLOSE of 16 at 61.78 on day 1
# Created SELL of -16 at 61.0 on day 2
# Created CLOSE of -16 at 61.37 on day 8
# Created BUY of 16 61.11 on day 23
# Created CLOSE of 16 at 60.35 on day 2
# Created SELL of -16 at 60.78 on day 3
# Created CLOSE of -16 at 60.66 on day 9
# Created BUY of 16 60.15 on day 23
# Created CLOSE of 16 at 61.57 on day 1
# Created SELL of -16 at 61.89 on day 2
# Created CLOSE of -16 at 62.44 on day 8
# Created BUY of 16 60.48 on day 23
# Created CLOSE of 16 at 61.62 on day 1
# Created SELL of -16 at 61.48 on day 4
# Created CLOSE of -16 at 61.93 on day 8
# Created BUY of 15 63.29 on day 25
# Created CLOSE of 15 at 63.76 on day 2
# Created SELL of -15 at 64.03 on day 3
# Created CLOSE of -15 at 64.78 on day 8
# Created BUY of 15 63.24 on day 23
# Created CLOSE of 15 at 64.91 on day 1
# Created SELL of -15 at 65.43 on day 2
# Created CLOSE of -15 at 66.04 on day 8
# Created BUY of 15 66.26 on day 23
# Created CLOSE of 15 at 63.08 on day 3
# Created SELL of -15 at 64.27 on day 4
# Created CLOSE of -15 at 64.45 on day 10
# Created BUY of 14 68.93 on day 24
# Created BUY of 13 70.96 on day 25
# Created CLOSE of 13 at 74.69 on day 1
# Created SELL of -13 at 74.97 on day 2
# Created CLOSE of -13 at 75.26 on day 8
# Created BUY of 12 82.72 on day 23
# Created CLOSE of 12 at 79.7 on day 2
# Created SELL of -12 at 77.64 on day 5
# Created CLOSE of -12 at 77.1 on day 8
# Created BUY of 13 73.77 on day 23
# Created CLOSE of 13 at 72.39 on day 2
# Created SELL of -13 at 70.67 on day 3
# Created CLOSE of -13 at 70.49 on day 9
# Created BUY of 12 72.04 on day 23
# Created CLOSE of 12 at 71.14 on day 2
# Created SELL of -12 at 70.66 on day 3
# Created CLOSE of -12 at 71.39 on day 9
# Created BUY of 12 70.96 on day 23
# Created CLOSE of 12 at 73.48 on day 1
# Created SELL of -12 at 72.58 on day 2
# Created CLOSE of -12 at 71.6 on day 8
# Created BUY of 13 70.17 on day 23
# Created CLOSE of 13 at 67.28 on day 1
# Created SELL of -13 at 67.51 on day 4
# Created CLOSE of -13 at 65.78 on day 8
# Created BUY of 14 63.83 on day 26
# Created CLOSE of 14 at 63.32 on day 1
# Created SELL of -14 at 63.66 on day 2
# Created CLOSE of -14 at 62.29 on day 8
# Created BUY of 14 65.11 on day 23
# Created CLOSE of 14 at 65.61 on day 1
# Created SELL of -14 at 65.76 on day 2
# Created CLOSE of -14 at 67.29 on day 8
# Created BUY of 14 63.47 on day 23
# Created CLOSE of 14 at 65.11 on day 3
# Created SELL of -15 at 64.6 on day 4
# Created CLOSE of -15 at 64.11 on day 10
# Created BUY of 14 66.8 on day 24
# Created CLOSE of 14 at 67.43 on day 1
# Created SELL of -14 at 68.41 on day 2
# Created CLOSE of -14 at 66.36 on day 8
# Created BUY of 14 67.71 on day 23
# Created CLOSE of 14 at 70.2 on day 1
# Created SELL of -14 at 69.71 on day 2
# Created CLOSE of -14 at 69.11 on day 8
# Created BUY of 15 66.86 on day 23
# Created CLOSE of 15 at 67.14 on day 2
# Created SELL of -16 at 66.47 on day 3
# Created CLOSE of -16 at 66.0 on day 9
# Created BUY of 15 67.11 on day 23
# Created CLOSE of 15 at 67.5 on day 1
# Created SELL of -15 at 67.55 on day 2
# Created CLOSE of -15 at 66.33 on day 8
# Created BUY of 16 64.24 on day 23
# Created CLOSE of 16 at 63.87 on day 4
# Created SELL of -16 at 64.28 on day 5
# Created CLOSE of -16 at 63.5 on day 8
# Created BUY of 16 65.13 on day 25
# Created CLOSE of 16 at 65.05 on day 1
# Created SELL of -16 at 65.24 on day 2
# Created CLOSE of -16 at 65.73 on day 8
# Created BUY of 16 64.57 on day 23
# Created CLOSE of 16 at 65.39 on day 1
# Created SELL of -16 at 65.31 on day 2
# Created CLOSE of -16 at 64.29 on day 8
# Created BUY of 16 65.1 on day 23
# Created CLOSE of 16 at 63.92 on day 1
# Created SELL of -17 at 62.86 on day 5
# Created CLOSE of -17 at 63.79 on day 8
# Created BUY of 16 64.75 on day 23
# Created CLOSE of 16 at 66.12 on day 3
# Created SELL of -16 at 67.31 on day 4
# Created CLOSE of -16 at 67.5 on day 10
# Created BUY of 15 70.73 on day 24
# Created CLOSE of 15 at 70.08 on day 1
# Created SELL of -15 at 69.41 on day 2
# Created CLOSE of -15 at 70.94 on day 8
# Created BUY of 14 71.81 on day 23
# Created CLOSE of 14 at 73.74 on day 1
# Created SELL of -14 at 73.15 on day 2
# Created CLOSE of -14 at 72.42 on day 8
# Created BUY of 14 72.42 on day 23
# Created CLOSE of 14 at 71.9 on day 2
# Created SELL of -15 at 72.32 on day 3
# Created CLOSE of -15 at 72.61 on day 9
# Created BUY of 13 77.22 on day 23
# Created CLOSE of 13 at 77.41 on day 1
# Created SELL of -13 at 76.59 on day 2
# Created CLOSE of -13 at 76.58 on day 8
# Created BUY of 13 76.61 on day 23
# Created CLOSE of 13 at 76.68 on day 1
# Created SELL of -13 at 76.88 on day 4
# Created CLOSE of -13 at 76.39 on day 8
# Created BUY of 14 74.52 on day 25
# Created CLOSE of 14 at 73.29 on day 1
# Created SELL of -14 at 74.25 on day 2
# Created CLOSE of -14 at 72.37 on day 8
# Created BUY of 15 71.68 on day 23
# Created CLOSE of 15 at 70.76 on day 1
# Created SELL of -15 at 70.57 on day 2
# Created CLOSE of -15 at 68.82 on day 8
# Created BUY of 16 68.57 on day 23
# Created CLOSE of 16 at 69.16 on day 3
# Created SELL of -16 at 69.24 on day 4
# Created CLOSE of -16 at 68.75 on day 10
# Created BUY of 16 67.79 on day 24
# Created CLOSE of 16 at 67.21 on day 1
# Created SELL of -16 at 67.22 on day 2
# Created CLOSE of -16 at 65.72 on day 8
# Created BUY of 16 67.73 on day 23
# Created CLOSE of 16 at 68.85 on day 1
# Created SELL of -16 at 67.8 on day 2
# Created CLOSE of -16 at 66.85 on day 8
# Created BUY of 16 69.4 on day 23
# Created CLOSE of 16 at 69.01 on day 1
# Created SELL of -16 at 69.08 on day 4
# Created CLOSE of -16 at 67.28 on day 8
# Created BUY of 16 69.58 on day 25
# Created CLOSE of 16 at 70.39 on day 2
# Created SELL of -16 at 70.79 on day 3
# Created CLOSE of -16 at 71.39 on day 9
# Created BUY of 16 72.0 on day 23
# Created CLOSE of 16 at 73.67 on day 1
# Created SELL of -16 at 72.27 on day 2
# Created CLOSE of -16 at 73.03 on day 8
# Created BUY of 16 73.48 on day 23
# Created CLOSE of 16 at 70.89 on day 1
# Created SELL of -16 at 71.04 on day 5
# Created CLOSE of -16 at 72.2 on day 8
# Created BUY of 15 71.92 on day 25
# Created CLOSE of 15 at 74.88 on day 1
# Created SELL of -15 at 77.13 on day 2
# Created CLOSE of -15 at 80.18 on day 8
# Created BUY of 13 83.09 on day 23
# Created CLOSE of 13 at 83.02 on day 1
# Created SELL of -13 at 85.72 on day 2
# Created CLOSE of -13 at 85.72 on day 8
# Created BUY of 12 92.06 on day 23
# Created CLOSE of 12 at 94.57 on day 3
# Created SELL of -13 at 93.37 on day 4
# Created CLOSE of -13 at 89.04 on day 10
# Created BUY of 14 86.56 on day 24
# Created CLOSE of 14 at 91.48 on day 1
# Created SELL of -14 at 90.33 on day 2
# Created CLOSE of -14 at 88.62 on day 8
# Created BUY of 13 93.87 on day 23
# Created CLOSE of 13 at 89.82 on day 1
# Created SELL of -13 at 91.08 on day 2
# Created CLOSE of -13 at 91.48 on day 8
# Created BUY of 13 90.79 on day 23
# Created CLOSE of 13 at 91.98 on day 3
# Created SELL of -13 at 90.89 on day 4
# Created CLOSE of -13 at 91.28 on day 9
# Created BUY of 13 89.52 on day 23
# Created CLOSE of 13 at 92.01 on day 1
# Created SELL of -13 at 91.97 on day 2
# Created CLOSE of -13 at 89.83 on day 8
# Created BUY of 14 90.12 on day 23
# Created CLOSE of 14 at 89.8 on day 1
# Created SELL of -14 at 90.65 on day 2
# Created CLOSE of -14 at 89.56 on day 8
# Created BUY of 14 87.6 on day 23
# Created CLOSE of 14 at 87.3 on day 2
# Created SELL of -15 at 85.79 on day 3
# Created CLOSE of -15 at 89.64 on day 9
# Created BUY of 13 91.48 on day 23
# Created CLOSE of 13 at 90.54 on day 1
# Created SELL of -13 at 91.18 on day 2
# Created CLOSE of -13 at 92.38 on day 8
# Created BUY of 12 95.97 on day 23
# Created CLOSE of 12 at 101.58 on day 1
# Created SELL of -12 at 100.78 on day 4
# Created CLOSE of -12 at 97.57 on day 8
# Created BUY of 13 98.84 on day 25
# Created CLOSE of 13 at 98.57 on day 2
# Created SELL of -13 at 97.81 on day 3
# Created CLOSE of -13 at 100.1 on day 9
# Created BUY of 12 102.14 on day 23
# Created CLOSE of 12 at 100.78 on day 1
# Created SELL of -12 at 101.35 on day 2
# Created CLOSE of -12 at 97.95 on day 8
# Created BUY of 13 97.77 on day 23
# Created CLOSE of 13 at 99.85 on day 4
# Created SELL of -13 at 99.38 on day 5
# Created CLOSE of -13 at 97.51 on day 10
# Created BUY of 13 96.07 on day 24
# Created CLOSE of 13 at 97.78 on day 1
# Created SELL of -13 at 97.65 on day 2
# Created CLOSE of -13 at 96.01 on day 8
# Created BUY of 14 96.42 on day 23
# Created CLOSE of 14 at 96.15 on day 1
# Created SELL of -14 at 96.08 on day 2
# Created CLOSE of -14 at 98.9 on day 8
# Created BUY of 13 97.62 on day 23
# Created CLOSE of 13 at 98.16 on day 3
# Created SELL of -13 at 98.73 on day 4
# Created CLOSE of -13 at 98.41 on day 10
# Created BUY of 14 96.09 on day 24
# Created CLOSE of 14 at 94.35 on day 2
# Created SELL of -14 at 93.08 on day 3
# Created CLOSE of -14 at 94.09 on day 8
# Created BUY of 13 94.77 on day 23
# Created CLOSE of 13 at 91.38 on day 1
# Created SELL of -13 at 92.55 on day 4
# Created CLOSE of -13 at 92.63 on day 8
# Created BUY of 13 94.38 on day 25
# Created CLOSE of 13 at 94.24 on day 1
# Created SELL of -13 at 93.74 on day 4
# Created CLOSE of -13 at 90.95 on day 8
# Created BUY of 14 92.91 on day 25
# Created CLOSE of 14 at 94.04 on day 1
# Created SELL of -14 at 93.66 on day 2
# Created CLOSE of -14 at 96.82 on day 8
# Created BUY of 13 97.3 on day 23
# Created CLOSE of 13 at 98.72 on day 1
# Created SELL of -13 at 98.59 on day 2
# Created CLOSE of -13 at 95.8 on day 8
# Created BUY of 14 92.85 on day 23
# Created CLOSE of 14 at 91.59 on day 3
# Created SELL of -14 at 90.74 on day 4
# Created CLOSE of -14 at 89.87 on day 10
# Created BUY of 14 86.86 on day 24
# Created CLOSE of 14 at 88.3 on day 1
# Created SELL of -14 at 88.25 on day 2
# Created CLOSE of -14 at 85.81 on day 8
# Created BUY of 15 87.1 on day 23
# Created CLOSE of 15 at 84.48 on day 1
# Created SELL of -15 at 85.41 on day 2
# Created CLOSE of -15 at 85.86 on day 8
# Created BUY of 15 83.62 on day 23
# Created CLOSE of 15 at 83.78 on day 3
# Created SELL of -15 at 83.6 on day 4
# Created CLOSE of -15 at 82.88 on day 9
# Created BUY of 15 84.96 on day 23
# Created CLOSE of 15 at 85.28 on day 1
# Created SELL of -15 at 85.41 on day 2
# Created CLOSE of -15 at 85.57 on day 8
# Created BUY of 15 87.3 on day 23
# Created CLOSE of 15 at 85.82 on day 1
# Created SELL of -15 at 85.9 on day 4
# Created CLOSE of -15 at 83.57 on day 8
# Created BUY of 16 84.22 on day 25
# Created BUY of 15 84.54 on day 26
# Created CLOSE of 15 at 83.76 on day 2
# Created SELL of -15 at 84.07 on day 3
# Created CLOSE of -15 at 83.62 on day 9
# Created BUY of 15 84.02 on day 23
# Created CLOSE of 15 at 83.09 on day 2
# Created SELL of -15 at 83.09 on day 3
# Created CLOSE of -15 at 83.42 on day 8
# Created BUY of 15 86.84 on day 23
# Created BUY of 14 87.41 on day 24
# Created CLOSE of 14 at 89.13 on day 3
# Created SELL of -15 at 88.18 on day 4
# Created CLOSE of -15 at 87.31 on day 10
# Created BUY of 15 86.75 on day 24
# Created CLOSE of 15 at 89.11 on day 3
# Created SELL of -15 at 87.77 on day 4
# Created CLOSE of -15 at 86.67 on day 10
# Created BUY of 15 89.08 on day 24
# Created CLOSE of 15 at 88.4 on day 1
# Created SELL of -15 at 87.9 on day 2
# Created CLOSE of -15 at 89.62 on day 8
# Created BUY of 14 90.92 on day 23
# Created CLOSE of 14 at 92.01 on day 1
# Created SELL of -14 at 92.58 on day 2
# Created CLOSE of -14 at 91.67 on day 8
# Created BUY of 14 92.57 on day 23
# Created CLOSE of 14 at 93.02 on day 2
# Created SELL of -14 at 91.88 on day 3
# Created CLOSE of -14 at 91.76 on day 9
# Created BUY of 15 91.78 on day 23
# Created CLOSE of 15 at 92.7 on day 1
# Created SELL of -15 at 91.71 on day 2
# Created CLOSE of -15 at 93.08 on day 8
# Created BUY of 14 95.1 on day 23
# Created CLOSE of 14 at 94.83 on day 1
# Created SELL of -14 at 94.58 on day 4
# Created CLOSE of -14 at 95.63 on day 8
# Created BUY of 13 97.46 on day 25
# Created CLOSE of 13 at 96.85 on day 2
# Created SELL of -13 at 97.39 on day 3
# Created CLOSE of -13 at 96.06 on day 8
# Created BUY of 13 95.79 on day 23
# Created CLOSE of 13 at 98.34 on day 1
# Created SELL of -14 at 97.48 on day 2
# Created CLOSE of -14 at 99.3 on day 8
# Created BUY of 13 99.48 on day 23
# Created CLOSE of 13 at 99.19 on day 3
# Created SELL of -13 at 99.5 on day 4
# Created CLOSE of -13 at 98.93 on day 10
# Created BUY of 13 100.22 on day 24
# Created CLOSE of 13 at 101.53 on day 1
# Created SELL of -13 at 100.55 on day 2
# Created CLOSE of -13 at 102.43 on day 8
# Created BUY of 12 103.24 on day 23
# Created CLOSE of 12 at 106.62 on day 2
# Created SELL of -12 at 108.3 on day 5
# Created CLOSE of -12 at 108.58 on day 8
# Created BUY of 12 112.86 on day 23
# Created CLOSE of 12 at 115.36 on day 2
# Created SELL of -12 at 112.92 on day 3
# Created CLOSE of -12 at 109.72 on day 9
# Created BUY of 13 107.4 on day 23
# Created CLOSE of 13 at 106.67 on day 2
# Created SELL of -13 at 106.28 on day 3
# Created CLOSE of -13 at 104.79 on day 9
# Created BUY of 12 110.44 on day 23
# Created CLOSE of 12 at 111.32 on day 1
# Created SELL of -13 at 110.14 on day 2
# Created CLOSE of -13 at 110.48 on day 8
# Created BUY of 13 108.07 on day 23
# Created CLOSE of 13 at 104.69 on day 1
# Created SELL of -13 at 103.7 on day 4
# Created CLOSE of -13 at 103.43 on day 8
# Created BUY of 13 103.39 on day 26
# Created CLOSE of 13 at 102.49 on day 1
# Created SELL of -13 at 101.06 on day 2
# Created CLOSE of -13 at 99.39 on day 8
# Created BUY of 14 98.1 on day 23
# Created CLOSE of 14 at 98.04 on day 1
# Created SELL of -14 at 98.36 on day 2
# Created CLOSE of -14 at 102.0 on day 8
# Created BUY of 13 102.68 on day 23
# Created CLOSE of 13 at 104.99 on day 3
# Created SELL of -13 at 104.16 on day 4
# Created CLOSE of -13 at 104.36 on day 10
# Created BUY of 12 107.38 on day 24
# Created CLOSE of 12 at 103.93 on day 1
# Created SELL of -13 at 103.03 on day 2
# Created CLOSE of -13 at 102.94 on day 8
# Created BUY of 13 103.7 on day 23
# Created CLOSE of 13 at 105.66 on day 1
# Created SELL of -13 at 106.3 on day 2
# Created CLOSE of -13 at 104.08 on day 8
# Created BUY of 13 105.14 on day 23
# Created CLOSE of 13 at 104.3 on day 2
# Created SELL of -13 at 103.45 on day 3
# Created CLOSE of -13 at 101.2 on day 9
# Created BUY of 13 103.33 on day 23
# Created CLOSE of 13 at 105.28 on day 1
# Created SELL of -13 at 105.31 on day 2
# Created CLOSE of -13 at 104.4 on day 8
# Created BUY of 14 104.04 on day 23
# Created CLOSE of 14 at 104.31 on day 4
# Created SELL of -14 at 103.89 on day 5
# Created CLOSE of -14 at 105.95 on day 8
# Created BUY of 13 108.24 on day 25
# Created CLOSE of 13 at 109.0 on day 1
# Created SELL of -13 at 111.02 on day 2
# Created CLOSE of -13 at 113.15 on day 8
# Created BUY of 12 113.13 on day 23
# Created CLOSE of 12 at 110.73 on day 1
# Created SELL of -12 at 111.18 on day 2
# Created CLOSE of -12 at 112.06 on day 8
# Created BUY of 12 111.64 on day 23
# Created CLOSE of 12 at 112.9 on day 1
# Created SELL of -12 at 112.97 on day 4
# Created CLOSE of -12 at 114.05 on day 8
# Created BUY of 12 110.44 on day 25
# Created CLOSE of 12 at 110.65 on day 2
# Created SELL of -12 at 112.04 on day 3
# Created CLOSE of -12 at 113.28 on day 9
# Created BUY of 12 112.92 on day 23
# Created CLOSE of 12 at 113.13 on day 1
# Created SELL of -12 at 113.95 on day 2
# Created CLOSE of -12 at 115.61 on day 8
# Created BUY of 12 114.7 on day 23
# Created BUY of 12 117.78 on day 24
# Created BUY of 11 120.72 on day 27
# Created CLOSE of 11 at 122.16 on day 1
# Created SELL of -11 at 123.69 on day 5
# Created CLOSE of -11 at 124.79 on day 8
# Created BUY of 11 120.54 on day 25
# Created CLOSE of 11 at 121.69 on day 1
# Created SELL of -11 at 120.43 on day 2
# Created CLOSE of -11 at 120.37 on day 8
# Created BUY of 11 121.91 on day 23
# Created CLOSE of 11 at 121.91 on day 1
# Created SELL of -11 at 120.92 on day 2
# Created CLOSE of -11 at 120.18 on day 8
# Created BUY of 12 119.34 on day 23
# Created CLOSE of 12 at 119.54 on day 3
# Created SELL of -12 at 118.14 on day 4
# Created CLOSE of -12 at 116.33 on day 10
# Created BUY of 12 115.98 on day 24
# Created CLOSE of 12 at 114.69 on day 1
# Created SELL of -12 at 115.19 on day 2
# Created CLOSE of -12 at 113.89 on day 8
# Created BUY of 14 105.61 on day 23
# Created CLOSE of 14 at 104.15 on day 1
# Created SELL of -14 at 104.92 on day 2
# Created CLOSE of -14 at 104.37 on day 8
# Created BUY of 14 103.83 on day 23
# Created CLOSE of 14 at 105.23 on day 3
# Created SELL of -14 at 105.63 on day 4
# Created CLOSE of -14 at 107.15 on day 9
# Created BUY of 13 106.55 on day 23
# Created CLOSE of 13 at 104.98 on day 1
# Created SELL of -14 at 104.93 on day 2
# Created CLOSE of -14 at 107.75 on day 8
# Created BUY of 13 106.36 on day 23
# Created CLOSE of 13 at 105.51 on day 1
# Created SELL of -13 at 105.13 on day 2
# Created CLOSE of -13 at 104.01 on day 8
# Created BUY of 13 106.37 on day 23
# Created CLOSE of 13 at 107.68 on day 3
# Created SELL of -13 at 107.09 on day 4
# Created CLOSE of -13 at 107.32 on day 10
# Created BUY of 13 108.79 on day 24
# Created CLOSE of 13 at 107.38 on day 1
# Created SELL of -13 at 107.93 on day 2
# Created CLOSE of -13 at 106.98 on day 8
# Created BUY of 13 108.67 on day 23
# Created CLOSE of 13 at 110.33 on day 1
# Created SELL of -13 at 111.64 on day 2
# Created CLOSE of -13 at 110.73 on day 8
# Created BUY of 13 113.56 on day 23
# Created CLOSE of 13 at 110.84 on day 3
# Created SELL of -13 at 110.87 on day 5
# Created CLOSE of -13 at 109.45 on day 10
# Created BUY of 13 111.5 on day 24
# Created CLOSE of 13 at 111.24 on day 1
# Created SELL of -13 at 111.3 on day 2
# Created CLOSE of -13 at 111.22 on day 8
# Created BUY of 12 113.61 on day 23
# Created CLOSE of 12 at 113.36 on day 1
# Created SELL of -12 at 115.15 on day 5
# Created CLOSE of -12 at 115.37 on day 8
# Created BUY of 13 113.57 on day 25
# Created CLOSE of 13 at 111.37 on day 2
# Created SELL of -13 at 111.48 on day 3
# Created CLOSE of -13 at 111.1 on day 9
# Created BUY of 13 111.3 on day 23
# Created CLOSE of 13 at 112.03 on day 1
# Created SELL of -13 at 112.52 on day 2
# Created CLOSE of -13 at 113.48 on day 8
# Created BUY of 13 113.87 on day 24
# Created CLOSE of 13 at 113.88 on day 1
# Created SELL of -12 at 113.93 on day 4
# Created CLOSE of -12 at 114.0 on day 8
# Created BUY of 13 112.85 on day 26
# Created BUY of 12 114.32 on day 27
# Created CLOSE of 12 at 113.16 on day 2
# Created SELL of -12 at 113.7 on day 3
# Created CLOSE of -12 at 113.29 on day 8
# Created BUY of 13 111.56 on day 23
# Created CLOSE of 13 at 109.07 on day 1
# Created SELL of -13 at 108.06 on day 2
# Created CLOSE of -13 at 107.25 on day 8
# Created BUY of 13 106.75 on day 23
# Created CLOSE of 13 at 108.04 on day 1
# Created SELL of -13 at 107.16 on day 2
# Created CLOSE of -13 at 107.47 on day 8
# Created BUY of 13 108.81 on day 23
# Created CLOSE of 13 at 110.59 on day 2
# Created SELL of -13 at 109.74 on day 3
# Created CLOSE of -13 at 110.07 on day 9
# Created BUY of 13 107.52 on day 23
# Created CLOSE of 13 at 107.68 on day 1
# Created SELL of -13 at 107.56 on day 2
# Created CLOSE of -13 at 107.94 on day 8
# Created BUY of 14 107.26 on day 23
# Created BUY of 13 108.11 on day 24
# Created CLOSE of 13 at 109.66 on day 1
# Created SELL of -13 at 108.86 on day 4
# Created CLOSE of -13 at 108.95 on day 8
# Created BUY of 13 110.11 on day 25
# Created CLOSE of 13 at 110.86 on day 2
# Created SELL of -13 at 111.46 on day 3
# Created CLOSE of -13 at 111.42 on day 9
# Created BUY of 14 108.96 on day 23
# Created CLOSE of 14 at 108.47 on day 1
# Created SELL of -14 at 108.62 on day 2
# Created CLOSE of -14 at 108.77 on day 8
# Created BUY of 13 111.75 on day 23
# Created CLOSE of 13 at 110.15 on day 4
# Created SELL of -13 at 109.86 on day 5
# Created CLOSE of -13 at 109.73 on day 10
# Created BUY of 14 107.19 on day 24
# Created CLOSE of 14 at 106.83 on day 1
# Created SELL of -14 at 107.48 on day 2
# Created CLOSE of -14 at 103.62 on day 8
# Created BUY of 14 104.78 on day 23
# Created CLOSE of 14 at 104.56 on day 1
# Created SELL of -15 at 103.26 on day 2
# Created CLOSE of -15 at 103.73 on day 8
# Created BUY of 14 106.16 on day 23
# Created CLOSE of 14 at 107.09 on day 3
# Created SELL of -14 at 108.88 on day 4
# Created CLOSE of -14 at 109.88 on day 10
# Created BUY of 14 112.38 on day 24
# Created CLOSE of 14 at 113.15 on day 2
# Created SELL of -13 at 114.44 on day 3
# Created CLOSE of -13 at 112.48 on day 8
# Created BUY of 14 111.45 on day 23
# Created CLOSE of 14 at 112.3 on day 1
# Created SELL of -14 at 111.8 on day 4
# Created CLOSE of -14 at 113.59 on day 8
# Created BUY of 14 112.53 on day 25
# Created CLOSE of 14 at 110.4 on day 1
# Created SELL of -14 at 111.26 on day 4
# Created CLOSE of -14 at 113.1 on day 8
# Created BUY of 13 116.35 on day 25
# Created CLOSE of 13 at 115.96 on day 1
# Created SELL of -13 at 116.18 on day 2
# Created CLOSE of -13 at 115.24 on day 8
# Created BUY of 13 114.28 on day 23
# Created CLOSE of 13 at 115.77 on day 1
# Created SELL of -13 at 115.22 on day 2
# Created CLOSE of -13 at 116.24 on day 8
# Created BUY of 12 119.29 on day 23
# Created CLOSE of 12 at 124.0 on day 3
# Created SELL of -12 at 122.59 on day 4
# Created CLOSE of -12 at 122.18 on day 10
# Created BUY of 12 123.97 on day 24
# Created CLOSE of 12 at 124.06 on day 1
# Created SELL of -12 at 125.01 on day 2
# Created CLOSE of -12 at 124.4 on day 8
# Created BUY of 12 123.1 on day 23
# Created CLOSE of 12 at 127.14 on day 1
# Created SELL of -12 at 128.32 on day 2
# Created CLOSE of -12 at 131.91 on day 8
# Created BUY of 11 137.2 on day 23
# Created CLOSE of 11 at 138.62 on day 3
# Created SELL of -11 at 138.83 on day 4
# Created CLOSE of -11 at 134.84 on day 9
# Created BUY of 12 133.58 on day 23
# Created CLOSE of 12 at 135.14 on day 1
# Created SELL of -12 at 135.47 on day 2
# Created CLOSE of -12 at 136.94 on day 8
# Created BUY of 12 131.57 on day 23
# Created CLOSE of 12 at 132.82 on day 1
# Created SELL of -12 at 131.07 on day 4
# Created CLOSE of -12 at 127.48 on day 8
# Created BUY of 12 132.58 on day 25
# Created CLOSE of 12 at 130.92 on day 2
# Created SELL of -12 at 133.66 on day 3
# Created CLOSE of -12 at 131.24 on day 9
# Created BUY of 12 129.37 on day 23
# Created CLOSE of 12 at 129.9 on day 2
# Created SELL of -12 at 131.9 on day 3
# Created CLOSE of -12 at 129.64 on day 8
# Created BUY of 12 133.62 on day 23
# Created CLOSE of 12 at 138.21 on day 3
# Created SELL of -12 at 136.35 on day 4
# Created CLOSE of -12 at 137.54 on day 10
# Created BUY of 12 142.69 on day 24
# Created CLOSE of 12 at 146.41 on day 2
# Created SELL of -11 at 148.68 on day 3
# Created CLOSE of -11 at 162.91 on day 9
# Created BUY of 10 157.88 on day 23
# Created CLOSE of 10 at 159.09 on day 1
# Created SELL of -10 at 160.1 on day 2
# Created CLOSE of -10 at 157.24 on day 8
# Created BUY of 10 162.33 on day 23
# Created CLOSE of 10 at 160.17 on day 1
# Created SELL of -10 at 159.41 on day 4
# Created CLOSE of -10 at 156.38 on day 8
# Created BUY of 11 155.76 on day 26
# Created CLOSE of 11 at 154.96 on day 1
# Created SELL of -11 at 154.4 on day 2
# Created CLOSE of -11 at 149.64 on day 8
# Created BUY of 11 154.02 on day 23
# Created CLOSE of 11 at 156.23 on day 1
# Created SELL of -11 at 156.39 on day 2
# Created CLOSE of -11 at 157.31 on day 8
# Created BUY of 10 162.28 on day 23
# Created CLOSE of 10 at 162.66 on day 3
# Created SELL of -10 at 164.21 on day 4
# Created CLOSE of -10 at 161.86 on day 10
# Created BUY of 11 158.81 on day 24
# Created CLOSE of 11 at 157.0 on day 1
# Created SELL of -11 at 158.5 on day 2
# Created CLOSE of -11 at 156.89 on day 8
# Created BUY of 11 157.61 on day 23
# Created CLOSE of 11 at 156.69 on day 1
# Created SELL of -11 at 156.1 on day 2
# Created CLOSE of -11 at 153.58 on day 8
# Created BUY of 11 151.56 on day 23
# Created CLOSE of 11 at 152.27 on day 2
# Created SELL of -11 at 151.38 on day 3
# Created CLOSE of -11 at 149.85 on day 9
# Created BUY of 12 154.37 on day 23
# Created CLOSE of 12 at 151.38 on day 1
# Created SELL of -12 at 150.18 on day 2
# Created CLOSE of -12 at 151.23 on day 8
# Created BUY of 12 150.74 on day 23
# Created CLOSE of 12 at 151.58 on day 4
# Created SELL of -12 at 150.45 on day 5
# Created CLOSE of -12 at 145.59 on day 8
# Created BUY of 12 147.86 on day 25
# Created CLOSE of 12 at 146.42 on day 1
# Created SELL of -12 at 145.47 on day 2
# Created CLOSE of -12 at 143.22 on day 8
# Created BUY of 13 136.56 on day 23
# Created CLOSE of 13 at 136.04 on day 1
# Created SELL of -13 at 136.05 on day 2
# Created CLOSE of -13 at 132.93 on day 8
# Created BUY of 14 132.6 on day 23
# Created CLOSE of 14 at 132.8 on day 1
# Created SELL of -14 at 132.22 on day 5
# Created CLOSE of -14 at 133.28 on day 8
# Created BUY of 13 135.26 on day 23
# Created CLOSE of 13 at 133.97 on day 3
# Created SELL of -13 at 134.88 on day 4
# Created CLOSE of -13 at 133.3 on day 10
# Created BUY of 14 133.64 on day 24
# Created CLOSE of 14 at 133.87 on day 1
# Created SELL of -14 at 134.18 on day 2
# Created CLOSE of -14 at 136.03 on day 8
# Created BUY of 13 138.77 on day 23
# Created CLOSE of 13 at 139.82 on day 1
# Created SELL of -13 at 140.66 on day 2
# Created CLOSE of -13 at 144.14 on day 8
# Created BUY of 12 144.02 on day 23
# Created CLOSE of 12 at 146.3 on day 2
# Created SELL of -12 at 146.38 on day 3
# Created CLOSE of -12 at 142.98 on day 9
# Created BUY of 13 146.09 on day 23
# Created CLOSE of 13 at 144.76 on day 1
# Created SELL of -13 at 145.39 on day 2
# Created CLOSE of -13 at 143.82 on day 8
# Created BUY of 13 144.24 on day 23
# Created CLOSE of 13 at 141.49 on day 1
# Created SELL of -13 at 141.13 on day 4
# Created CLOSE of -13 at 138.12 on day 8
# Created BUY of 13 140.09 on day 25
# Created CLOSE of 13 at 142.74 on day 1
# Created SELL of -13 at 143.37 on day 2
# Created CLOSE of -13 at 145.25 on day 8
# Created BUY of 13 140.85 on day 23
# Created CLOSE of 13 at 148.67 on day 1
# Created SELL of -13 at 148.85 on day 2
# Created CLOSE of -13 at 144.81 on day 8
# Created BUY of 14 145.1 on day 23
# Created CLOSE of 14 at 140.98 on day 3
# Created SELL of -14 at 140.4 on day 4
# Created CLOSE of -14 at 139.33 on day 10
# Created BUY of 14 139.17 on day 24
# Created CLOSE of 14 at 138.65 on day 1
# Created SELL of -14 at 139.12 on day 2
# Created CLOSE of -14 at 135.18 on day 8
# Created BUY of 14 133.72 on day 23
# Created CLOSE of 14 at 138.43 on day 1
# Created SELL of -15 at 133.69 on day 2
# Created CLOSE of -15 at 134.97 on day 8
# Created BUY of 15 128.83 on day 23
# Created CLOSE of 15 at 129.89 on day 1
# Created SELL of -15 at 128.98 on day 4
# Created CLOSE of -15 at 122.76 on day 8
# Created BUY of 18 118.91 on day 25
# Created BUY of 17 120.1 on day 26
# Created CLOSE of 17 at 115.17 on day 2
# Created SELL of -18 at 115.94 on day 3
# Created CLOSE of -18 at 112.7 on day 9
# Created BUY of 18 114.56 on day 23
# Created CLOSE of 18 at 114.43 on day 1
# Created SELL of -18 at 114.49 on day 2
# Created CLOSE of -18 at 112.34 on day 8
# Created BUY of 19 112.38 on day 23

# %% [markdown]
# # Convert result to DF

# %%
# Get the strategy returns as a dictionary
returns_dict = backtest_result[0].analyzers.time_return.get_analysis()

# Convert the dictionary to a DataFrame
returns_df = (
    pd.DataFrame(
        list(returns_dict.items()),
        columns = ["date", "return"]
    )
    .set_index("date")
)

# %% [markdown]
# # Assess results

# %%
bench = openbb.stocks.load(
    "TLT",
    start_date="2002-01-01",
    end_date="2022-06-30"
)["Adj Close"]

qs.reports.metrics(
    returns_df,
    benchmark=bench,
    mode="full"
)
# Out:
# Loading Daily data for TLT with starting period 2002-07-30.
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               2002-07-30  2002-07-30
# End Period                 2022-06-29  2022-06-29
# Risk-Free Rate             0.0%        0.0%
# Time in Market             55.0%       100.0%
#
# Cumulative Return          114.8%      171.88%
# CAGR﹪                     3.91%       5.15%
#
# Sharpe                     0.47        0.43
# Prob. Sharpe Ratio         98.25%      97.19%
# Smart Sharpe               0.45        0.41
# Sortino                    0.68        0.61
# Smart Sortino              0.65        0.59
# Sortino/√2                 0.48        0.43
# Smart Sortino/√2           0.46        0.41
# Omega                      1.12        1.12
#
# Max Drawdown               -27.69%     -34.76%
# Longest DD Days            2555        1086
# Volatility (ann.)          8.97%       14.06%
# R^2                        0.01        0.01
# Information Ratio          -0.01       -0.01
# Calmar                     0.14        0.15
# Skew                       -0.07       0.05
# Kurtosis                   7.01        4.27
#
# Expected Daily %           0.02%       0.02%
# Expected Monthly %         0.32%       0.42%
# Expected Yearly %          3.71%       4.88%
# Kelly Criterion            3.62%       3.87%
# Risk of Ruin               0.0%        0.0%
# Daily Value-at-Risk        -0.91%      -1.43%
# Expected Shortfall (cVaR)  -0.91%      -1.43%
#
# Max Consecutive Wins       9           11
# Max Consecutive Losses     10          7
# Gain/Pain Ratio            0.12        0.08
# Gain/Pain (1M)             0.49        0.42
#
# Payoff Ratio               0.98        0.96
# Profit Factor              1.12        1.08
# Common Sense Ratio         1.22        1.04
# CPC Index                  0.57        0.55
# Tail Ratio                 1.09        0.97
# Outlier Win Ratio          8.97        3.07
# Outlier Loss Ratio         3.45        2.88
#
# MTD                        1.65%       -2.13%
# 3M                         6.66%       -11.81%
# 6M                         5.83%       -22.62%
# YTD                        5.9%        -22.56%
# 1Y                         16.32%      -19.32%
# 3Y (ann.)                  11.19%      -3.21%
# 5Y (ann.)                  8.08%       0.33%
# 10Y (ann.)                 5.02%       1.27%
# All-time (ann.)            3.91%       5.15%
#
# Best Day                   3.75%       7.52%
# Worst Day                  -4.9%       -6.67%
# Best Month                 8.82%       14.34%
# Worst Month                -6.54%      -13.07%
# Best Year                  17.49%      34.0%
# Worst Year                 -12.95%     -22.56%
#
# Avg. Drawdown              -2.57%      -3.94%
# Avg. Drawdown Days         81          84
# Recovery Factor            4.15        4.95
# Ulcer Index                0.11        0.11
# Serenity Index             0.31        0.71
#
# Avg. Up Month              1.81%       3.42%
# Avg. Down Month            -1.84%      -2.83%
# Win Days %                 52.32%      52.9%
# Win Month %                57.92%      53.75%
# Win Quarter %              66.25%      57.5%
# Win Year %                 71.43%      71.43%
#
# Beta                       0.07        -
# Alpha                      0.04        -
# Correlation                11.27%      -
# Treynor Ratio              1597.82%    -
